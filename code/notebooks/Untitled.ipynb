# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/processed/TCE-DAT_historic-exposure_1950-2015_cl_distances.csv')

# %%
df
# Out:
#       year     IBTrACS_ID  TC_name NatCatSERVICE_ID genesis_basin  \
# 0     1950  1950166N14262  UNNAMED              NaN            EP
# 1     1950  1950174N17126    ELSIE              NaN            WP
# 2     1950  1950174N17126    ELSIE              NaN            WP
# 3     1950  1950185N18254  UNNAMED              NaN            EP
# 4     1950  1950191N12149  UNNAMED              NaN            WP
# ...    ...            ...      ...              ...           ...
# 5330  2015  2015309N14067     MEGH              NaN            NI
# 5331  2015  2015309N14067     MEGH              NaN            NI
# 5332  2015  2015312N11083  UNNAMED              NaN            NI
# 5333  2015  2015344N07145    MELOR              NaN            WP
# 5334  2015  2015355S16136  UNNAMED              NaN            SP
#
#      countries_affected ISO3  v_land_SI  v_land_kn      pop_34kn  ...  \
# 0                single  MEX       47.3       92.0  1.435042e+06  ...
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    display(df.groupby('ISO3')[['TC_name', 'pop_34kn', 'pop_96kn_5km']].count())
# Out:
#       TC_name  pop_34kn  pop_96kn_5km
# ISO3
# ABW        12        12             0
# AIA        33        33             0
# AND         1         1             0
# ANT        46        46             0
# ASM        13        13             0
# ATG        38        38             0
# AUS       243       243           243
# BGD        54        54             0
# BHS        81        81             0
# BLZ        29        29             0
# BRA         2         2             0
# BRB        27        27             0
# BRN         1         1             0
# CAN       102       102           102
# CHN       569       569           569
# COL        12        12             0
# COM         9         9             0
# CPV        25        25             0
# CRI         4         4             0
# CUB        75        75             0
# DMA        37        37             0
# DOM        44        44            44
# DZA         1         1             0
# ...
